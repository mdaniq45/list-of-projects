# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([1,3,5,7,9])
y=x*2

# %%
plt.plot(x,y)

# %%
x=np.arange(1,16)
y=x*2
z=(y/2)+40

# %%
fig=plt.figure()

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color="g",label='line1')
ax.plot(x,z,color="b",label='line2')
ax.set_title('title of the plot',fountsize=15)
ax.setx_label(label for x axis',fountsize=15)
ax.set_ylabel("label for y axis",fountsize=15)
              ax
