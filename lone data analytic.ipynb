# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt
import seaborn as sns

# %%
dataset=pd.read_csv("C:\\Users\\hi\\Expanded_data_with_more_features.csv")

# %%
dataset.head(7)
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0           0  female         NaN   bachelor's degree      standard
# 1           1  female     group C        some college      standard
# 2           2  female     group B     master's degree      standard
# 3           3    male     group A  associate's degree  free/reduced
# 4           4    male     group C        some college      standard
# 5           5  female     group B  associate's degree      standard
# 6           6  female     group B        some college      standard
#
#     TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0       none             married     regularly          yes         3.0
# 1        NaN             married     sometimes          yes         0.0
# 2       none              single     sometimes          yes         4.0
# 3       none             married         never           no         1.0
# ...

# %%
dataset.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  11040.000000  10472.000000  11040.000000  11040.000000  11039.000000
# mean     491.028804      2.125000     66.689493     69.441757     68.449316
# std      286.041837      1.471642     15.442964     14.747144     15.435190
# min        0.000000      0.000000      0.000000      8.000000      6.000000
# 25%      245.000000      1.000000     56.000000     59.000000     58.000000
# 50%      488.000000      2.000000     67.000000     70.000000     69.000000
# 75%      733.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %%
dataset.shape
# Out:
# (11040, 15)

# %%
dataset.isnull()
# Out:
#        Unnamed: 0  Gender  EthnicGroup  ParentEduc  LunchType  TestPrep  \
# 0           False   False         True       False      False     False
# 1           False   False        False       False      False      True
# 2           False   False        False       False      False     False
# 3           False   False        False       False      False     False
# 4           False   False        False       False      False     False
# ...           ...     ...          ...         ...        ...       ...
# 11035       False   False        False       False      False     False
# 11036       False   False         True       False      False     False
# 11037       False   False        False        True      False     False
# 11038       False   False        False       False      False     False
# 11039       False   False        False       False      False     False
#
#        ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup             665
# ParentEduc              658
# LunchType                 0
# TestPrep                659
# ParentMaritalStatus     435
# PracticeSport           224
# IsFirstChild            362
# NrSiblings              568
# TransportMeans         1140
# WklyStudyHours          339
# MathScore                 0
# ReadingScore              0
# WritingScore              1
# dtype: int64

# %%
#dataset.isnotnull().sum()

# %%
sns.heatmap(dataset.isnull())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 sns.heatmap(dataset.isnull())
# ----> 2 plt.show()
#
# File d:\Users\hi\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
dataset.shape
# Out:
# (11040, 15)

# %%
dataset.drop(columns=["TransportMeans "],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dataset.drop(columns=["TransportMeans "],inplace=True)
#
# File d:\Users\hi\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
dataset.fillna(10)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female          10   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 11035         693    male     group D         high school      standard
# 11036         694    male          10    some high school      standard
# 11037         695    male     group C                  10  free/reduced
# 11038         696  female     group B         high school      standard
# 11039         697  female     group C   bachelor's degree  free/reduced
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11040 entries, 0 to 11039
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           11040 non-null  int64
#  1   Gender               11040 non-null  object
#  2   EthnicGroup          10375 non-null  object
#  3   ParentEduc           10382 non-null  object
#  4   LunchType            11040 non-null  object
#  5   TestPrep             10381 non-null  object
#  6   ParentMaritalStatus  10605 non-null  object
#  7   PracticeSport        10816 non-null  object
#  8   IsFirstChild         10678 non-null  object
#  9   NrSiblings           10472 non-null  float64
#  10  TransportMeans       9900 non-null   object
#  11  WklyStudyHours       10701 non-null  object
#  12  MathScore            11040 non-null  int64
#  13  ReadingScore         11040 non-null  int64
#  14  WritingScore         11039 non-null  float64
# ...

# %%
#dataset.fillna(method=bfill,axis=1)

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup             665
# ParentEduc              658
# LunchType                 0
# TestPrep                659
# ParentMaritalStatus     435
# PracticeSport           224
# IsFirstChild            362
# NrSiblings              568
# TransportMeans         1140
# WklyStudyHours          339
# MathScore                 0
# ReadingScore              0
# WritingScore              1
# dtype: int64

# %%
input_data=dataset.iloc[:,:-1]
output_data=dataset.iloc[:,:-1]

# %%
ss=standardscaler()
ss.fit_transfprm(input_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ss=standardscaler()
#       2 ss.fit_transfprm(input_data)
#
# NameError: name 'standardscaler' is not defined
