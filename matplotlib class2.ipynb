# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[4,5,7,3,6]
y=[7,5,8,3,6]

# %%
plt.bar(x,y)
c=['r','g','y','b']
plt.bar(x,y,color=c)
plt.plot()
# Out:
# []

# %%
x=[5,7,9,0,10]
y=[4,3,2,6,8]
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
x=['python','java','c']
y=[90,80,94]
plt.xlabel('tranding languabes',fontsize=15)
plt.ylabel('numbers',fontsize=10)

plt.bar(x,y,width=0.4,color=c , edgecolor='y', linewidth=4,linestyle=':' ,label='populiriy' )
plt.legend()

# %%
x=[5,34,53,56,64,7,87]
y=[55,76,4,34,35,77,13]
size=[5,34,53,56,64,7,87]
plt.title('scatterplot')
plt.scatter(x,y)

# %%
x=['python','java','c','r']
y=[98,80,89,87]
plt.xlabel('languages',fontsize=15)
plt.ylabel('no',fontsize=15)
plt.title('programing languages',fontsize=15)\
c=['r',b','g','y']
plt.bar(x,y,width=0.5,color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
x=[55,7,5,44]
y=['c','c++','python','r']
plt.pie(x,labels=y, explode=ex,autopct="%.2f%%",shadow=True,radius=1.5,startangle=0)
tex
ex=[0.1,0.3,0,0]
