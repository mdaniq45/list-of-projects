# %%
import pandas as pd
pd.DataFrame({'yes':[40,50],'No':[323.422]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 pd.DataFrame({'yes':[40,50],'No':[323.422]})
#
# File E:\Users\hi\anaconda3\Lib\site-packages\pandas\core\frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# File E:\Users\hi\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.dataframe({'bob':['i love you','i hate  you']'sue':['pretty good','pland']})
# Out:
#   Cell In[7], line 1
#     pd.dataframe({'bob':['i love you','i hate  you']'sue':['pretty good','pland']})
#                         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.Series([1,2,34,5])
# Out:
# 0     1
# 1     2
# 2    34
# 3     5
# dtype: int64

# %%
pd.Series([32,42,5],index=['2014 sale','2015 sale','2026 sale']
,name='product A')
# Out:
# 2014 sale    32
# 2015 sale    42
# 2026 sale     5
# Name: product A, dtype: int64

# %% [markdown]
# #write csv file
# import pandas as pd
# dis={(1:[1,2,3,4,5],2:[5,7,54,30,6]}
# p=pd.dataFrame(dis)
# print(d)

# %%
dis={"a":[343,43,63,346,436],"s":[96,6,5,4,4]}
d=pd.DataFrame(dif)
print(d)
d.to_csv("test _new.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 dis={"a":[343,43,63,346,436],"s":[96,6,5,4,4]}
# ----> 2 d=pd.DataFrame(dif)
#       3 print(d)
#       4 d.to_csv("test _new.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
import pandas as pd
data=pd.read_csv('f55')


df.head()
# Out:
#   Cell In[4], line 2
#     data=pd.read_csv('C:\Users\hi\OneDrive\Desktop\csv \\filesf55')
#                                                                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# import numpy as np
# data=np.array(['a','b','c','d'])
# s=pd.series(data)
# print (s)

# %%
#import the pandas library and aliasing as pd
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data,index=[100,200,300,400])
print( s)
# Out:
# 100    a
# 200    b
# 300    c
# 400    d
# dtype: object

# %% [raw]
# #write csv file
# import pandas as pd

# %%
dis={"a":[1,2,3,45],"s":[424,6564,

d=pd.DataFrame(dis)

# %% [raw]
# #csv files

# %%
import pandas as pd
data=[1,2,3,4,5,6]
s=pd.DataFrame(data)

# %%
#type(df)

# %%
data=[['avm','vcc','mas'],['mvs','mcr','erd']]
df=pd.DataFrame(data)
df
# Out:
#      0    1    2
# 0  avm  vcc  mas
# 1  mvs  mcr  erd

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data={'name':[['ama','mla','uvl','olm'],[1,2,3,4]]}
df=pd.DataFrame(data)
df
# Out:
#                    name
# 0  [ama, mla, uvl, olm]
# 1          [1, 2, 3, 4]

# %% [markdown]
# #todat pracrice session

# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['zama','mohammad','ali','ahamed','ahed'],
    "marks":[99,98,98,90,92],
    "city":['nawada','bihar','jhr','oridisha','ghi']
}

# %%
pd.DataFrame(dict1)
# Out:
#        name  marks      city
# 0      zama     99    nawada
# 1  mohammad     98     bihar
# 2       ali     98       jhr
# 3    ahamed     90  oridisha
# 4      ahed     92       ghi

# %%
df.to_csv('dict1.csv')

# %%
df.head(2)
# Out:
#     Name  Age         City
# 0  Alice   25     New York
# 1    Bob   30  Los Angeles

# %%
df.tail()
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   30.0
# std     5.0
# min    25.0
# 25%    27.5
# 50%    30.0
# 75%    32.5
# max    35.0

# %%
ser=pd.Series(np.random.random(150))
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,6),index=np.arange(334))
newdf.head()
# Out:
#           0         1         2         3         4         5
# 0  0
# 5    0.198678  0.604863  0.597061  0.239130  0.217588  0.800632
# ..        ...       ...       ...       ...       ...       ...
# 329  0.547096  0.567801  0.827499  0.130297  0.865731  0.505108
# 330  0.865144  0.138227  0.447244  0.473131  0.464074  0.882325
# 331  0.341463  0.673207  0.978573  0.259279  0.876231  0.072117
# 332  0.481207  0.835462  0.060498  0.813244  0.290551  0.403839
# 333  0.180163  0.791089  0.015283  0.905186  0.537885  0.302003
#
# [333 rows x 6 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4         5
# 0        64  0.321067  0.034065  0.113240  0.831748  0.784745
# 1  0.498468  0.979571  0.173619  0.822348  0.207436  0.835849
# 2  0.442548  0.353250  0.796218  0.083115  0.773841  0.880553
# 3  0.229483  0.704686  0.712311  0.612626  0.425405  0.781782
# 4  0.315615  0.288083  0.178892  0.445989  0.773433  0.755162

# %%
newdf.loc[(newdf[0]<1.12)&(newdf[3]>0.10)]
# Out:
#             0         1         2         3         4         5
# 1    0.498468  0.979571  0.173619  0.822348  0.207436  0.835849
# 3    0.229483  0.704686  0.712311  0.612626  0.425405  0.781782
# 4    0.315615  0.288083  0.178892  0.445989  0.773433  0.755162
# 5    0.198678  0.604863  0.597061  0.239130  0.217588  0.800632
# 6    0.274126  0.055768  0.287982  0.201032  0.017295  0.200604
# ..        ...       ...       ...       ...       ...       ...
# 329  0.547096  0.567801  0.827499  0.130297  0.865731  0.505108
# 330  0.865144  0.138227  0.447244  0.473131  0.464074  0.882325
# 331  0.341463  0.673207  0.978573  0.259279  0.876231  0.072117
# 332  0.481207  0.835462  0.060498  0.813244  0.290551  0.403839
# 333  0.180163  0.791089  0.015283  0.905186  0.537885  0.302003
#
# [289 rows x 6 columns]

# %%
newdf.iloc[0,4]
# Out:
# 0.83174806805365

# %%
newdf.drop(0)
# Out:
#             0         1         2         3         4         5
# 1    0.498468  0.979571  0.173619  0.822348  0.207436  0.835849
# 2    0.442548  0.353250  0.796218  0.083115  0.773841  0.880553
# 3    0.229483  0.704686  0.712311  0.612626  0.425405  0.781782
# 4    0.315615  0.288083  0.178892  0.445989  0.773433  0.755162
# 5    0.198678  0.604863  0.597061  0.239130  0.217588  0.800632
# ..        ...       ...       ...       ...       ...       ...
# 329  0.547096  0.567801  0.827499  0.130297  0.865731  0.505108
# 330  0.865144  0.138227  0.447244  0.473131  0.464074  0.882325
# 331  0.341463  0.673207  0.978573  0.259279  0.876231  0.072117
# 332  0.481207  0.835462  0.060498  0.813244  0.290551  0.403839
# 333  0.180163  0.791089  0.015283  0.905186  0.537885  0.302003
#
# [333 rows x 6 columns]

# %%
  newdf[2].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: 2, Length: 334, dtype: bool

# %%
df.max()
# Out:
# Name     Charlie
# Age           35
# City    New York
# dtype: object

# %%
df.min()
# Out:
# Name      Alice
# Age          25
# City    Chicago
# dtype: object
